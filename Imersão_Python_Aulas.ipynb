# %% [markdown]
# <a href="https://colab.research.google.com/github/heltonalberto/api_gestao_financeira/blob/main/Imers%C3%A3o_Python_Aulas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Aula 2 - Importação**

# %%
import pandas as pd

# %%
df_plan1 = pd.read_excel("/content/acoes_pura.xlsx", sheet_name="Plan1")
df_plan1
# Out:
#     Ativo       Data  Último (R$)  Var. Dia (%)  Var. Sem. (%)  Var. Mês (%)  \
# 0   USIM5 2024-01-26         9.50          5.20          11.76          2.26
# 1   CMIN3 2024-01-26         6.82          2.40           2.40        -12.11
# 2   PETR3 2024-01-26        41.96          2.19           7.73          7.64
# 3   SUZB3 2024-01-26        52.91          2.04           2.14         -4.89
# 4   CPFE3 2024-01-26        37.10          2.03           2.49         -3.66
# ..    ...        ...          ...           ...            ...           ...
# 76  CRFB3 2024-01-26        10.71         -2.45          -9.47        -13.98
# 77  BHIA3 2024-01-26         8.70         -2.46          -6.95        -23.55
# 78  RENT3 2024-01-26        56.24         -3.63          -6.41        -11.57
# 79  CVCB3 2024-01-26         3.07         -4.36          -5.54        -12.29
# 80  GOLL4 2024-01-26         5.92         -8.07         -15.91        -34.00
#
# ...

# %%
df_plan2 = pd.read_excel("/content/acoes_pura.xlsx", sheet_name="Plan2")
df_plan2
# Out:
#                       Código  Qtde. Teórica
# 0                      RRRP3   2.356656e+08
# 1                      ALOS3   5.326166e+08
# 2                      ALPA4   1.767340e+08
# 3                      ABEV3   4.394246e+09
# 4                      ARZZ3   6.230589e+07
# ..                       ...            ...
# 84                     VBBR3   1.114413e+09
# 85                     WEGE3   1.481593e+09
# 86                     YDUQ3   2.893479e+08
# 87  Quantidade Teórica Total   9.637210e+10
# 88                   Redutor   1.704785e+07
#
# [89 rows x 2 columns]

# %%
df_plan3 = pd.read_excel("/content/acoes_pura.xlsx", sheet_name="Plan3")
df_plan3
# Out:
#     Ticker            Nome
# 0    MGLU3  Magazine Luiza
# 1    HAPV3         Hapvida
# 2    PETR4       Petrobras
# 3    B3SA3              B3
# 4    USIM5        Usiminas
# ..     ...             ...
# 530  TKNO3           Tekno
# 531  COCE6          Coelce
# 532  MGEL3         Mangels
# 533  CTSA8      Santanense
# 534  MMAQ4   Minasmáquinas
#
# [535 rows x 2 columns]

# %%
df_plan4 = pd.read_excel("/content/acoes_pura.xlsx", sheet_name="Plan4")
df_plan4
# Out:
#         Nome da Empresa                      Setor  Idade (anos)
# 0        Magazine Luiza                     Varejo            64
# 1               Hapvida                      Saúde            46
# 2             Petrobras         Energia/Óleo e Gás            69
# 3                    B3       Serviços Financeiros           128
# 4              Usiminas     Siderurgia e Mineração            60
# ..                  ...                        ...           ...
# 84               Klabin           Papel e Celulose           123
# 85  Azevedo & Travassos                Agronegócio            51
# 86             Profarma  Distribuição Farmacêutica            57
# 87           AES Brasil                    Energia            25
# 88           Odontoprev       Planos Odontológicos            26
#
# [89 rows x 3 columns]

# %%
df_plan1 = df_plan1[['Ativo',	'Data',	'Último (R$)',	'Var. Dia (%)']].copy()
df_plan1
# Out:
#     Ativo       Data  Último (R$)  Var. Dia (%)
# 0   USIM5 2024-01-26         9.50          5.20
# 1   CMIN3 2024-01-26         6.82          2.40
# 2   PETR3 2024-01-26        41.96          2.19
# 3   SUZB3 2024-01-26        52.91          2.04
# 4   CPFE3 2024-01-26        37.10          2.03
# ..    ...        ...          ...           ...
# 76  CRFB3 2024-01-26        10.71         -2.45
# 77  BHIA3 2024-01-26         8.70         -2.46
# 78  RENT3 2024-01-26        56.24         -3.63
# 79  CVCB3 2024-01-26         3.07         -4.36
# 80  GOLL4 2024-01-26         5.92         -8.07
#
# [81 rows x 4 columns]

# %%
df_plan1 = df_plan1.rename(columns={'Último (R$)':'valorFinal', 'Var. Dia (%)':'varDiaPct'}).copy()
df_plan1
# Out:
#     Ativo       Data  valorFinal  varDiaPct
# 0   USIM5 2024-01-26        9.50       5.20
# 1   CMIN3 2024-01-26        6.82       2.40
# 2   PETR3 2024-01-26       41.96       2.19
# 3   SUZB3 2024-01-26       52.91       2.04
# 4   CPFE3 2024-01-26       37.10       2.03
# ..    ...        ...         ...        ...
# 76  CRFB3 2024-01-26       10.71      -2.45
# 77  BHIA3 2024-01-26        8.70      -2.46
# 78  RENT3 2024-01-26       56.24      -3.63
# 79  CVCB3 2024-01-26        3.07      -4.36
# 80  GOLL4 2024-01-26        5.92      -8.07
#
# [81 rows x 4 columns]
